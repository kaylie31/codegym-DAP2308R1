# %%
import pandas as pd

df = pd.read_csv('FoodPrice_in_Turkey.csv')

# %%
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df_price = df.loc[:, 'Price']
df_price.head()
# Out:
# 0    4.4920
# 1    4.5786
# 2    4.7865
# 3    5.1337
# 4    5.5099
# Name: Price, dtype: float64

# %%
df_price.count()
# Out:
# 7381

# %%
df_price.min()
# Out:
# 0.2539

# %%
df_price.max()
# Out:
# 159.4458

# %%
df_price.mean()
# Out:
# 15.738708576073702

# %%
df_price.mode()
# Out:
# 0    0.4118
# Name: Price, dtype: float64

# %%
df_price.median()
# Out:
# 5.9096

# %% [markdown]
# Nếu: Mode > Median > Mean: Dữ liệu có phân bố lệch trái.
#
# Nếu: Mode = Median = Mean: Dữ liệu có phân bố đối xứng (phân bố chuẩn).
#
# Nếu: Mode < Median < Mean: Dữ liệu có phân bố lệch phải.

# %%
df.describe()
# Out:
#          ProductId         UmId        Month         Year        Price
# count  7381.000000  7381.000000  7381.000000  7381.000000  7381.000000
# mean    254.509687    15.252811     6.479881  2017.458474    15.738709
# std     141.008599    25.276665     3.530361     1.499256    22.418284
# min      52.000000     5.000000     1.000000  2013.000000     0.253900
# 25%     114.000000     5.000000     3.000000  2017.000000     3.223600
# 50%     239.000000     5.000000     6.000000  2018.000000     5.909600
# 75%     388.000000     5.000000    10.000000  2019.000000    20.441900
# max     502.000000   102.000000    12.000000  2019.000000   159.445800

# %%
df_place = df.loc[:, 'Place']

# %%
df_place.count()
# Out:
# 7381

# %%
df_place.min()
# Out:
# 'Ankara'

# %%
df_place.max()
# Out:
# 'National Average'

# %%
df_place.mode()
# Out:
# 0    National Average
# Name: Place, dtype: object

# %% [markdown]
# # Pivot Table

# %% [markdown]
# pandas.pivot_table(values=’a’, index=’b’, columns=’c’, aggfunc='mean’)

# %%
df.pivot_table(values='Price', index='ProductName', columns='Year', aggfunc= 'mean')
# Out:
# Year                                                     2013       2014  \
# ProductName
# Apples (red) - Retail                                2.080950   2.410118
# Apples - Retail                                           NaN        NaN
# Bananas - Retail                                     4.002225   4.962827
# Beans (white) - Retail                               6.932800   9.484309
# Bread (common) - Retail                              2.853000   3.069491
# Bread (pita) - Retail                                     NaN        NaN
# Bulgur - Retail                                      2.405025   2.593791
# Cabbage - Retail                                     1.104800   1.073233
# Cauliflower - Retail                                 2.046950   2.129317
# Cheese - Retail                                           NaN        NaN
# Chickpeas - Retail                                   5.918450   5.815827
# Cocoa (powder) - Retail                             37.795150  38.134264
# ...

# %%
df.pivot_table(values = 'Price', columns= 'Year', aggfunc= 'max')
# Out:
# Year      2013     2014   2015   2016     2017      2018     2019
# Price  40.1146  39.7204  65.54  76.96  93.9628  159.4458  150.038

# %%
df.pivot_table(values='Price', index = 'ProductName', aggfunc='max')
# Out:
#                                                        Price
# ProductName
# Apples (red) - Retail                                 2.9800
# Apples - Retail                                       6.0925
# Bananas - Retail                                     12.9400
# Beans (white) - Retail                               13.0975
# Bread (common) - Retail                               6.1942
# Bread (pita) - Retail                                 2.5600
# Bulgur - Retail                                       5.2611
# Cabbage - Retail                                      3.2543
# Cauliflower - Retail                                  5.9113
# Cheese - Retail                                      35.5297
# Chickpeas - Retail                                   15.5274
# Cocoa (powder) - Retail                              54.8237
# Coffee (instant) - Retail                            61.3502
# Coffee - Retail                                      54.9968
# ...

# %%
df.pivot_table(values='Price', index='Month', columns='Place', aggfunc = {min, max})
# Out:
# /var/folders/7b/s694fx0d6wb04bgqp_b182140000gn/T/ipykernel_80104/2718302221.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.pivot_table(values='Price', index='Month', columns='Place', aggfunc = {min, max})
# /var/folders/7b/s694fx0d6wb04bgqp_b182140000gn/T/ipykernel_80104/2718302221.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.pivot_table(values='Price', index='Month', columns='Place', aggfunc = {min, max})
#             max                                          min                   \
# Place    Ankara  Istanbul     Izmir National Average  Ankara Istanbul   Izmir
# Month
# ...

# %%
import numpy as np
df.pivot_table(values = ['Price', 'Month'], index= 'ProductName', columns = 'Place', aggfunc= {'Price': np.sum, 'Month': np.mean})
# Out:
# /var/folders/7b/s694fx0d6wb04bgqp_b182140000gn/T/ipykernel_80104/4279351568.py:2: FutureWarning: The provided callable <function sum at 0x1062bae80> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(values = ['Price', 'Month'], index= 'ProductName', columns = 'Place', aggfunc= {'Price': np.sum, 'Month': np.mean})
# /var/folders/7b/s694fx0d6wb04bgqp_b182140000gn/T/ipykernel_80104/4279351568.py:2: FutureWarning: The provided callable <function mean at 0x1062bbf60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.pivot_table(values = ['Price', 'Month'], index= 'ProductName', columns = 'Place', aggfunc= {'Price': np.sum, 'Month': np.mean})
#                                                    Month                   \
# ...

# %%
# [Thực hành] Hợp nhất các cột dữ liệu từ nhiều data frame

# %%
# Xóa các dòng có thuộc tính ProductID trùng nhau, giữ lại bản ghi cuối cùng, giữ chỉ số ban đầu của các dòng
df=df.drop_duplicates(['ProductId'], keep='last')
df.head()
# Out:
#               Place  ProductId                      ProductName  UmId UmName  \
# 0  National Average        176             Tea (green) - Retail    33   Unit
# 1  National Average        212       Peas (green, dry) - Retail     5     KG
# 2  National Average        229            Apples (red) - Retail     5     KG
# 3  National Average        233  Cucumbers (greenhouse) - Retail     5     KG
# 4  National Average        384            Bread (pita) - Retail     5     KG
#
#    Month  Year  Price
# 0      3  2017   4.65
# 1      6  2015   3.29
# 2      3  2017   2.83
# 3      3  2017   4.24
# 4      3  2017   2.48

# %%
# Xóa các dòng có thuộc tính ProductID trùng nhau, giữ lại bản ghi cuối cùng, thiết lập lại chỉ số
df=df.drop_duplicates(['ProductId'], keep='last').reset_index(drop=True)
df.head()
# Out:
#               Place  ProductId                      ProductName  UmId UmName  \
# 0  National Average        176             Tea (green) - Retail    33   Unit
# 1  National Average        212       Peas (green, dry) - Retail     5     KG
# 2  National Average        229            Apples (red) - Retail     5     KG
# 3  National Average        233  Cucumbers (greenhouse) - Retail     5     KG
# 4  National Average        384            Bread (pita) - Retail     5     KG
#
#    Month  Year  Price
# 0      3  2017   4.65
# 1      6  2015   3.29
# 2      3  2017   2.83
# 3      3  2017   4.24
# 4      3  2017   2.48

# %%
df_pro = df.loc[:, ['ProductId', 'ProductName', 'UmId', 'UmName']]
df_pro.head()
# Out:
#    ProductId                      ProductName  UmId UmName
# 0        176             Tea (green) - Retail    33   Unit
# 1        212       Peas (green, dry) - Retail     5     KG
# 2        229            Apples (red) - Retail     5     KG
# 3        233  Cucumbers (greenhouse) - Retail     5     KG
# 4        384            Bread (pita) - Retail     5     KG

# %%
# Tách file chứa thông tin giá
df_pri = df.loc[:,['ProductId','Place','Month','Year','Price']]
df_pri.head()
# Out:
#    ProductId             Place  Month  Year  Price
# 0        176  National Average      3  2017   4.65
# 1        212  National Average      6  2015   3.29
# 2        229  National Average      3  2017   2.83
# 3        233  National Average      3  2017   4.24
# 4        384  National Average      3  2017   2.48

# %%
# Tách file chứa thông tin giá với số dòng từ bản ghi 10 đến 20
df_pri10 = df.loc[10:20,['ProductId','Place','Month','Year','Price']]
df_pri10
# Out:
#     ProductId  Place  Month  Year    Price
# 10         92  Izmir     12  2019   0.6301
# 11         94  Izmir     12  2019  11.7723
# 12         97  Izmir     12  2019   5.5038
# 13        105  Izmir     12  2019  38.4497
# 14        108  Izmir     12  2019   7.5267
# 15        112  Izmir     12  2019   4.9827
# 16        114  Izmir     12  2019   4.7359
# 17        119  Izmir     12  2019  33.0362
# 18        124  Izmir     12  2019   5.9795
# 19        151  Izmir     12  2019  51.5925
# 20        173  Izmir     12  2019   2.2126

# %%
# Cách 1: Dùng phương thức merge ghép 2 dataFrame có cùng chung một cột thuộc tính. 
# DataFrame mới được tạo ra gồm các thuộc tính riêng và thuộc tính chung. 
# Cú pháp cơ bản: pd.merge(dataFram1,dataFram2,on=’Tên thuộc tính chung’).
df1 = pd.merge(df_pro, df_pri, on = 'ProductId')
df1.head()
# Out:
#    ProductId                      ProductName  UmId UmName             Place  \
# 0        176             Tea (green) - Retail    33   Unit  National Average
# 1        212       Peas (green, dry) - Retail     5     KG  National Average
# 2        229            Apples (red) - Retail     5     KG  National Average
# 3        233  Cucumbers (greenhouse) - Retail     5     KG  National Average
# 4        384            Bread (pita) - Retail     5     KG  National Average
#
#    Month  Year  Price
# 0      3  2017   4.65
# 1      6  2015   3.29
# 2      3  2017   2.83
# 3      3  2017   4.24
# 4      3  2017   2.48

# %%
# Cách 2: Dùng phương thức concat cho phép ghép từ hai dataFrame trở lên lại với nhau
# Các dataFrame không cần cột thuộc tính chung, dataFrame mới được tạo ra bao gồm tất cả các cột thuộc tính của các dataFrame cần ghép. 
# Tham số axis = 1 có nghĩa là dữ liệu được ghép theo cột. 
# Cú pháp cơ bản: pd.concat([dataFram1,dataFram2,…], axis=1).

df2 = pd.concat([df_pro, df_pri], axis= 1)
df2.head()
# Out:
#    ProductId                      ProductName  UmId UmName  ProductId  \
# 0        176             Tea (green) - Retail    33   Unit        176
# 1        212       Peas (green, dry) - Retail     5     KG        212
# 2        229            Apples (red) - Retail     5     KG        229
# 3        233  Cucumbers (greenhouse) - Retail     5     KG        233
# 4        384            Bread (pita) - Retail     5     KG        384
#
#               Place  Month  Year  Price
# 0  National Average      3  2017   4.65
# 1  National Average      6  2015   3.29
# 2  National Average      3  2017   2.83
# 3  National Average      3  2017   4.24
# 4  National Average      3  2017   2.48

# %%
df3=pd.concat([df_pro,df_pri,df_pri10], axis=1)
df3.head()
# Out:
#    ProductId                      ProductName  UmId UmName  ProductId  \
# 0        176             Tea (green) - Retail    33   Unit        176
# 1        212       Peas (green, dry) - Retail     5     KG        212
# 2        229            Apples (red) - Retail     5     KG        229
# 3        233  Cucumbers (greenhouse) - Retail     5     KG        233
# 4        384            Bread (pita) - Retail     5     KG        384
#
#               Place  Month  Year  Price  ProductId Place  Month  Year  Price
# 0  National Average      3  2017   4.65        NaN   NaN    NaN   NaN    NaN
# 1  National Average      6  2015   3.29        NaN   NaN    NaN   NaN    NaN
# 2  National Average      3  2017   2.83        NaN   NaN    NaN   NaN    NaN
# 3  National Average      3  2017   4.24        NaN   NaN    NaN   NaN    NaN
# 4  National Average      3  2017   2.48        NaN   NaN    NaN   NaN    NaN
